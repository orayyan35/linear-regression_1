# %% [markdown]
# ## linear regression
# (one varilable regression or unvariate regression )

# %%
import numpy as np

# %% [markdown]
#      input X = مدخلات
#      output Y = المخرجات
#      row m = الصفوف
#      Features n  = العناصر
#      h(x) = القيمه المتوقعه
#      cost J = قيمه الخطأ
#      theta = معاملات X

# %% [markdown]
# ![Screenshot%202023-09-13%20at%2023.20.22.png](attachment:Screenshot%202023-09-13%20at%2023.20.22.png)

# %% [markdown]
# The goal is to find the values of theta one (θ1) and theta two (θ2) that minimize the error rate as much as possible.

# %% [markdown]
# -----

# %% [markdown]
# sample example for linear regression equation :

# %%
theta0 = 5 #(θ0)
theta1 = 2 #(θ1)
# eqation h(x)= (θ0) + (θ1X)

# %% [markdown]
# # h(x) is :

# %%
def h(x):
    return [5 + 2 * xi for xi in x]
# Assume x and y are lists of house areas and prices
x = [1, 2, 2, 3, 4, 5, 5]
y = [7, 8, 7, 9, 11, 10, 12]
expect = h(x)
print(expect)
# Out:
# [7, 9, 9, 11, 13, 15, 15]

# %% [markdown]
# the Value (expect) It is the expected value of the price of homes

# %% [markdown]
# -------

# %% [markdown]
# # the h(x) - y :-

# %%
expect = np.array([7, 9, 9, 11, 13, 15, 15])
y = np.array([7, 8, 7, 9, 11, 10, 12])
result = expect - y
print(result)
# Out:
# [0 1 2 2 2 5 3]

# %% [markdown]
# -----

# %% [markdown]
# m = It is the value of the number of rows and we will use (len() from numpy )

# %% [markdown]
# x = it is vlaue of the area house

# %% [markdown]
# y = it is vlaue of the house price

# %% [markdown]
# h(x) = it is value of the expect price house

# %% [markdown]
# ----

# %% [markdown]
# # we will square h(x)- y
#
# ![Screenshot%202023-09-14%20at%200.22.50.png](attachment:Screenshot%202023-09-14%20at%200.22.50.png)

# %%
squared_matrix = np.square(result) 
squared_matrix
# Out:
# array([ 0,  1,  4,  4,  4, 25,  9])

# %%
sum_matrix = np.sum(squared_matrix)
print(sum_matrix)
# Out:
# 47

# %% [markdown]
# # the cost Functions  is :-
#
#
# ![Screenshot%202023-09-14%20at%200.28.37.png](attachment:Screenshot%202023-09-14%20at%200.28.37.png)
#
#      m
#
#     sum of the martixe
#
#     square of the matrixe

# %%
m= len(squared_matrix)

# %%
#j = 1 / 2*m * sum_matrix

# %%
j=sum_matrix/ (2*m)

# %%
j
# Out:
# 3.357142857142857

# %% [markdown]
# ------

# %% [markdown]
# ![Screenshot%202023-09-14%20at%200.33.27.png](attachment:Screenshot%202023-09-14%20at%200.33.27.png)

# %% [markdown]
# So the error value of this prediction is equal to j
# and i try minimize j using (θ0) (θ1)
